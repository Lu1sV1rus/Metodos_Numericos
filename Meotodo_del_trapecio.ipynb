# %% [markdown]
# <a href="https://colab.research.google.com/github/Lu1sV1rus/Metodos_Numericos/blob/main/Meotodo_del_trapecio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import sympy as sp

# variables simbolicas
x , y ,z = sp.symbols('x y z')

d=1.5
c=1
b=2
a=1.4
vi=0
#Integrales

def fun(y):
  fx=x**2*y
  return fx

def funt(x):
  fw=fun(c)+fun(d)
  return fw


def trapecio(a,b,c,d):
  h1=d-c
  h2=b-a
  f1=(h1/2)*(fun(c)+fun(d))
  f=(h2/2)*(funt(a)+funt(b))
  print(f1)
  return f


print((trapecio(a,b,c,d)))
print("error",abs((vi)-trapecio(a,b,c,d)))
print("------")
# Out:
# 0.625*x**2
# 1.5*x**2
# 0.625*x**2
# error 1.5*Abs(x**2)
# ------
