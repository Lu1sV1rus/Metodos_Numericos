# %% [markdown]
# <a href="https://colab.research.google.com/github/Lu1sV1rus/Metodos_Numericos/blob/main/PuntoFijo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
#Punto Fijo
#Simultaneas
def simul(x,y,z):
  print("Simultaneas")
  print("k  |         x            |           y          |           z         |    error")
  for i in range(j):
    x1=fun(x,y,z,1)
    y1=fun(x,y,z,2)
    z1=fun(x,y,z,3)
    if x1>y1:
       if x1>z1:
          cj=x1

       else:
          cj:
    error=((x1-x)**2+(y1-y)**2+(z1-z)**2)**(1/2)
    print(i," | ",x1," | ",y1," | ",z1," | ",error)
    if error<=limerror:
      print("---")
      break
    x=x1
    y=y1
    z=z1

#Sucesivas
def suces(x,y,z):
  print("Sucesivas")
  print("k  |         x            |           y          |           z         |    error")
  for i in range(j):
    x1=x
    y1=y
    z1=z
    x=fun(x,y,z,1)
    y=fun(x,y,z,2)
    z=fun(x,y,z,3)
    error=((x-x1)**2+(y-y1)**2+(z-z1)**2)**(1/2)
    print(i," | ",x," | ",y," | ",z," | ",error)
    if error<=limerror:
      print("---")
      break

# %%
#Intervalo
x=1
y=-1
z=2
#Error
limerror=1*10**(-4)
#Numero de rep
j=15
def fun(x,y,z,w):
  #Ecuaciones
  fx=-2*x+y+3*z
  fy=x+3*y-z
  fz=3*x-y+2*z
  if w==1:
    return fx
  if w==2:
    return fy
  if w==3:
    return fz

simul(x,y,z)
print("")
print(" ---------------- ")
print("")
suces(x,y,z)
# Out:
# Simultaneas
# k  |         x            |           y          |           z         |    error
# 0  |  3  |  -4  |  8  |  7.0
# 1  |  14  |  -17  |  29  |  27.03701166919155
# 2  |  42  |  -66  |  117  |  104.54185764563398
# 3  |  201  |  -273  |  426  |  404.48856596942267
# 4  |  603  |  -1044  |  1728  |  1565.6465118282606
# 5  |  2934  |  -4257  |  6309  |  6061.558462969733
# 6  |  8802  |  -16146  |  25677  |  23471.28392312615
# 7  |  43281  |  -65313  |  93906  |  90892.19862562463
# 8  |  129843  |  -246564  |  382968  |  351996.7964186606
# 9  |  642654  |  -992817  |  1402029  |  1363214.5771854848
# 10  |  1927962  |  -3737826  |  5724837  |  5279560.594387473
# 11  |  9580761  |  -15010353  |  20971386  |  20447309.209515344
# 12  |  28742283  |  -56421684  |  85695408  |  79191295.50906797
# 13  |  143179974  |  -226218177  |  314039349  |  306704726.97355354
# 14  |  429539922  |  -849513906  |  1283836797  |  1187858020.032494
#
#  ----------------
# ...

# %%
import math
#Punto Fijo
#Simultaneas
def simul(x,y,z):
  print("Simultaneas")
  print("k  |         x            |           y          |           z         |    error")
  for i in range(j):
    x1=fun(x,y,z,1)
    y1=fun(x,y,z,2)
    z1=fun(x,y,z,3)
    error=((x1-x)**2+(y1-y)**2+(z1-z)**2)**(1/2)
    print(i," | ",x1," | ",y1," | ",z1," | ",error)
    if error<=limerror:
      print("---")
      break
    x=x1
    y=y1
    z=z1
